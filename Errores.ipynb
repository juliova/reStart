# %%
variable=0
variable = variable + 1
print(variable)
#Ambas variables deben ser del mismo tipo. Cambiar ambas a int o string
# Out:
# 1

# %%
#Porque siempre muestra "verdad"?
variable=True

if variable:
    print("verdad")
else:
    print("No es verdad")
#lo que muestra depende de la variable. Si esta es igual a True entonces hace lo que está dentro del "if" (imprimir "verdad"). 
#Si fuera False entonces hace lo que esta dentro del "else" (imprimir "No es verdad")
# Out:
# verdad

# %%
#Modificar la instrucción "if" para que este programa tenga sentido. Solo modificar la linea del if.
saldo=150
montoTransferencia=200
if saldo >= montoTransferencia:
  print("Transferencia realizada")
else:
  print("Fondos insuficientes")
# Para que realice una transferencia deben de haber fondos suficientes. La transferencia se debe comparar con el saldo para
# ver que si hay suficiente dinero.
# Out:
# Fondos insuficientes

# %%
#asignar a la variable "impuesto" el 2% de "montoTransferencia"
montoTransferencia=200
impuesto= montoTransferencia * 0.02
print("La transferencia {} tiene un impuesto de: {}".format(montoTransferencia, impuesto))
# Multiplicar por 0.02
# Out:
# La transferencia 200 tiene un impuesto de: 4.0

# %%
#terminar programa para que calcule el promedio de la lista "numeros"
numeros=[34,5,6,767,879,9]
suma=0
for n in numeros:
    #AQUI falta codigo...
    suma += n

promedio=suma/len(numeros)
print(promedio)
# Calcular el total de la suma de los numeros de la lista. Promedio es igual a la suma dividido por la cantidad de numeros.
# Out:
# 283.3333333333333
